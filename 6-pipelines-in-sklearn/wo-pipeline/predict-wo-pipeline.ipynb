# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open("models/ohe_sex.pkl", "rb"))
ohe_embarked = pickle.load(open("models/ohe_embarked.pkl", "rb"))
clf = pickle.load(open("models/clf.pkl", "rb"))

# %% [markdown]
# Creating a input

# %%
# Pclass, sex, age, SibSp, Parch, Fare, Embarked
test_input = np.array([2, "male", 31.0, 0, 0, 10.5, "S"], dtype=object).reshape(1, 7)

test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %% [markdown]
# Now again need to apply all the transformation to this data input and then predict

# %%
test_input_sex = ohe_sex.transform(test_input[:, 1].reshape(1, 1))
test_input_sex
# Out:
# c:\Users\thahi\codes\lifeCodes\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:, -1].reshape(1, 1))
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:, 2].reshape(1, 1)

# %%
test_input_transformed = np.concatenate((test_input[:, [0, 3, 4, 5]], test_input_sex, test_input_age, test_input_embarked), axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %% [markdown]
# Predicting

# %%
clf.predict(test_input_transformed)
# Out:
# array([1])

# %% [markdown]
# 1 is the prediction i.e person will survive
