# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(columns=["PassengerId", "Pclass", "Name", "Sex", "Age", "Fare", "Embarked"], inplace=True)

# %%
df.head(1)
# Out:
#    Survived  SibSp  Parch     Ticket Cabin
# 0         0      1      0  A/5 21171   NaN

# %%
df["Number"] = df["SibSp"] + df["Parch"]
df.head(1)
# Out:
#    Survived  SibSp  Parch     Ticket Cabin  Number
# 0         0      1      0  A/5 21171   NaN       1

# %%
df.drop(columns=["SibSp", "Parch"], inplace=True)
df.sample(10)
# Out:
#      Survived           Ticket Cabin  Number
# 405         0            28664   NaN       1
# 256         1         PC 17585   NaN       0
# 687         0           349228   NaN       0
# 392         0          3101277   NaN       2
# 471         0           315089   NaN       0
# 261         1           347077   NaN       6
# 86          0       W./C. 6608   NaN       4
# 827         1  S.C./PARIS 2079   NaN       2
# 600         1           243847   NaN       3
# 77          0           374746   NaN       0

# %%
df["Number"] = df["Number"].replace(0, "A")
df.head()
# Out:
#    Survived            Ticket Cabin Number
# 0         0         A/5 21171   NaN      1
# 1         1          PC 17599   C85      1
# 2         1  STON/O2. 3101282   NaN      A
# 3         1            113803  C123      1
# 4         0            373450   NaN      A

# %%
df["Number"].unique()
# Out:
# array([1, 'A', 4, 2, 6, 5, 3, 7, 10], dtype=object)

# %% [markdown]
# ### Look we have mixed values now - numerical and categorical in a single column

# %% [markdown]
# Extracting Numerical Part

# %%
df["Number_numerical"] = pd.to_numeric(df["Number"], errors="coerce", downcast="integer")

# %%
df["Number_categorical"] = np.where(df["Number_numerical"].isnull(), df["Number"], np.nan)

# np.where(condition, x, y) returns an array with elements from x in a row where condition is True, and elements from y at other rows

# x = np.where(
#     1 > 2,
#     "yes correct",
#     "wrong"
# )
# x will be wrong

# %%
df.head()
# Out:
#    Survived            Ticket Cabin Number  Number_numerical  \
# 0         0         A/5 21171   NaN      1               1.0
# 1         1          PC 17599   C85      1               1.0
# 2         1  STON/O2. 3101282   NaN      A               NaN
# 3         1            113803  C123      1               1.0
# 4         0            373450   NaN      A               NaN
#
#   Number_categorical
# 0                NaN
# 1                NaN
# 2                  A
# 3                NaN
# 4                  A

# %% [markdown]
# ### Number column is handled. Now lets handle at Cabin and Ticket

# %% [markdown]
# ### Cabin

# %%
pd.DataFrame(df["Cabin"].unique())
# Out:
#         0
# 0     NaN
# 1     C85
# 2    C123
# 3     E46
# 4      G6
# ..    ...
# 143   E17
# 144   A24
# 145   C50
# 146   B42
# 147  C148
#
# [148 rows x 1 columns]

# %% [markdown]
# Here you see that each value contains both numeric and categorical

# %% [markdown]
# Extracting numerical part of Cabin

# %%
df["Cabin_numerical"] = df["Cabin"].str.extract("(\\d+)")
df.sample(10)
# Out:
#      Survived    Ticket Cabin Number  Number_numerical Number_categorical  \
# 774         1     29105   NaN      4               4.0                NaN
# 693         0      2672   NaN      A               NaN                  A
# 193         1    230080    F2      2               2.0                NaN
# 276         0    347073   NaN      A               NaN                  A
# 386         0   CA 2144   NaN      7               7.0                NaN
# 830         1      2659   NaN      1               1.0                NaN
# 203         0      2628   NaN      A               NaN                  A
# 334         1  PC 17611   NaN      1               1.0                NaN
# 580         1    237789   NaN      2               2.0                NaN
# 218         1     11813   D15      A               NaN                  A
#
#     Cabin_numerical
# 774             NaN
# 693             NaN
# 193               2
# 276             NaN
# 386             NaN
# 830             NaN
# 203             NaN
# 334             NaN
# 580             NaN
# 218              15

# %% [markdown]
# Extracting categorical part of Cabin

# %%
df["Cabin_categorical"] = df["Cabin"].str[0]
df.sample(10)
# Out:
#      Survived    Ticket Cabin Number  Number_numerical Number_categorical  \
# 198         1    370370   NaN      A               NaN                  A
# 207         1      2699   NaN      A               NaN                  A
# 658         0     29751   NaN      A               NaN                  A
# 176         0      4133   NaN      4               4.0                NaN
# 831         1     29106   NaN      2               2.0                NaN
# 187         1    111428   NaN      A               NaN                  A
# 269         1  PC 17760   C99      A               NaN                  A
# 697         1     35852   NaN      A               NaN                  A
# 360         0    347088   NaN      5               5.0                NaN
# 124         0     35281   D26      1               1.0                NaN
#
#     Cabin_numerical Cabin_categorical
# 198             NaN               NaN
# 207             NaN               NaN
# 658             NaN               NaN
# 176             NaN               NaN
# 831             NaN               NaN
# 187             NaN               NaN
# 269              99                 C
# 697             NaN               NaN
# 360             NaN               NaN
# 124              26                 D

# %% [markdown]
# ### Now Ticket

# %%
pd.DataFrame(df["Ticket"].unique()).head()
# Out:
#                   0
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %% [markdown]
# Extracting the last bit of Ticket i.e the number

# %%
df["Ticket_numerical"] = df["Ticket"].apply(lambda s: s.split()[-1])

pd.DataFrame(df["Ticket_numerical"]).head()
# Out:
#   Ticket_numerical
# 0            21171
# 1            17599
# 2          3101282
# 3           113803
# 4           373450

# %%
df["Ticket_numerical"] = pd.to_numeric(df["Ticket_numerical"],
                                       errors="coerce",
                                       downcast="integer")

pd.DataFrame(df["Ticket_numerical"].head())
# Out:
#    Ticket_numerical
# 0           21171.0
# 1           17599.0
# 2         3101282.0
# 3          113803.0
# 4          373450.0

# %% [markdown]
# Extracting first part i.e. the letters

# %%
df["Ticket_categorical"] = df["Ticket"].apply(lambda s: s.split()[0])

pd.DataFrame(df["Ticket_categorical"]).head()
# Out:
#   Ticket_categorical
# 0                A/5
# 1                 PC
# 2           STON/O2.
# 3             113803
# 4             373450

# %% [markdown]
# Notice, in rows where there were no letters, the numbers only were considered as the first part so they got into the dataframe

# %%
df["Ticket_categorical"] = np.where(df["Ticket_categorical"].str.isdigit(), np.nan, df["Ticket_categorical"])

pd.DataFrame(df["Ticket_categorical"]).head()
# Out:
#   Ticket_categorical
# 0                A/5
# 1                 PC
# 2           STON/O2.
# 3                NaN
# 4                NaN
